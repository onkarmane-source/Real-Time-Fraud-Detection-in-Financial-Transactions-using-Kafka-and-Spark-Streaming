# %%
pip install confluent_kafka
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached confluent_kafka-2.8.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.8 MB)
# ...
# Python interpreter will be restarted.

# %%
pip install faker
# Out:
# Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.

# %%
from confluent_kafka import Producer
import json
import random
from faker import Faker
import time

# %%
fake = Faker()
conf = {
    'bootstrap.servers': 'pkc-l7pr2.ap-south-1.aws.confluent.cloud:9092',
    'security.protocol': 'SASL_SSL',
    'sasl.mechanism': 'PLAIN',
    'sasl.username': 'JRZT5522HUYXIP5U',
    'sasl.password': 'ua/rCAM1Hknml5A4DOs1NqeRS8za119RZ0qdWF72zb4ERpZXLn/MTtcC6a5ICdja'
}

# %%
producer = Producer(conf)
def generate_transactions():
    transaction = {
        "transaction_id" : fake.uuid4(),
        "timestamp":int(time.time()),
        "user_id":random.randint(10000,99999),
        "amount":round(random.uniform(5,5000),2),
        "transaction_type":random.choice(["purchase","transfer","withdrawal"]),
        "location":fake.city(),
        "mearchant":fake.company(),
        "card_number":fake.credit_card_number()
    }
    return transaction

def delivery_report(err,msg):
    if err is not None:
        print(f"message is not delivered: {err}")
    else:
        print(f"msg delivered to {msg.topic()},{[{msg.partition()}]},{msg}")


while True :
    txn = generate_transactions()
    producer.produce("txndata",value = json.dumps(txn),key = str(txn['user_id']),callback = delivery_report)
    producer.flush()
    time.sleep(1)
# Out:
# msg delivered to txndata,[{2}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{3}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{1}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{2}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{5}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{0}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{1}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{2}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{1}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{3}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{2}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{0}],<cimpl.Message object at 0x7f5e9038e740>
# msg delivered to txndata,[{3}],<cimpl.Message object at 0x7f5e9038e740>
# ...
